# %% [markdown]
# <a href="https://colab.research.google.com/github/leekangwoo/AIB-18-discussion/blob/main/n114a_Data_Wrangling(2)_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://user-images.githubusercontent.com/6457691/89746244-a6e2a200-daf3-11ea-9314-7863d544d73c.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 1 / NOTE 4*
#
# # 📝 Assignment
#
# ---

# %% [markdown]
# # **🌱 기본 과제**

# %% [markdown]
# ## **Part 1. Data Wranling**

# %% [markdown]
# ### **1-1. 데이터 불러오기**
# - 데이터 프레임을 불러오세요.
# - `info()`를 통해 데이터의 정보를 확인하세요.
# - `isnull()`를 통해 데이터에 missing values가 존재하는지 확인하세요.

# %%
# 데이터 업로드
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
final_revised = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/11_/data/Assignment/final_revised.csv')
final_revised.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    711 non-null    object
#  1   Series_Title   711 non-null    object
#  2   Released_Year  711 non-null    int64
#  3   Certificate    711 non-null    object
#  4   Runtime        711 non-null    object
#  5   Genre          711 non-null    object
#  6   IMDB_Rating    711 non-null    float64
#  7   Overview       711 non-null    object
#  8   Meta_score     711 non-null    float64
#  9   Director       711 non-null    object
#  10  Star1          711 non-null    object
#  11  Star2          711 non-null    object
#  12  Star3          711 non-null    object
#  13  Star4          711 non-null    object
#  14  No_of_Votes    711 non-null    float64
#  15  Gross          711 non-null    object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 89.0+ KB

# %%
final_revised.isnull()
# Out:
#      Poster_Link  Series_Title  Released_Year  Certificate  Runtime  Genre  \
# 0          False         False          False        False    False  False
# 1          False         False          False        False    False  False
# 2          False         False          False        False    False  False
# 3          False         False          False        False    False  False
# 4          False         False          False        False    False  False
# ..           ...           ...            ...          ...      ...    ...
# 706        False         False          False        False    False  False
# 707        False         False          False        False    False  False
# 708        False         False          False        False    False  False
# 709        False         False          False        False    False  False
# 710        False         False          False        False    False  False
#
# ...

# %% [markdown]
# ### **1-2. EDA**

# %% [markdown]
# ##### **Q1. `Gross` column의 최대값과 75% 사분위값의 차이를 구하세요.**
# - `.replace()`와 `.astype()`을 활용하여 `Gross` column의 데이터 타입을 `Integer`로 변경하세요.
# - `.max()` 함수와 `quantile(q=0.75)` 함수를 활용하여 최대값과 75% 사분위값의 차이를 확인하세요.
# - 두 값의 차는 양수가 나와야 합니다.

# %%
# final_revised.Gross = final_revised.Gross.str.replace(',', '')
# final_revised.Gross = final_revised.Gross.str.extract('(\d+)').astype('int')
final_revised.Gross = final_revised.Gross.str.replace(',', '').astype('int')

# %%
final_revised.Gross.describe()
print(final_revised.Gross.max() - final_revised.Gross.quantile(q=0.75))
# Out:
# 834371417.0

# %% [markdown]
# ##### **Q2. 최대값과 75% 사분위값 사이에 수치적으로 큰 차이가 존재할 때, 무엇을 의심해볼 수 있을까요?**
#
# 1. 결측치(Missing Values)
# 2. 중복값(Duplicates)
# 3. 이상치(Outliers)
# 4. 정답 없음

# %%
# 3. 이상치(Outliers)

# %% [markdown]
# ##### **Q3. `Runtime` column의 평균값을 반올림하여 소수점 둘째 자리까지 구하세요.**
# - `.extract()`와 `.astype()`을 활용하여 `Runtime` column의 데이터 타입을 `Integer`로 변경하세요.
# - `Runtime` column의 평균값을 확인하세요.

# %%
# final_revised.Runtime = final_revised.Runtime.str.replace(r'min', '').astype('int')
final_revised.Runtime = final_revised.Runtime.str.extract('(\d+)').astype('int')

# %%
# final_revised.Runtime.head(10)
print(f'{final_revised.Runtime.mean():.2f}')
# Out:
# 123.70

# %% [markdown]
# ##### **Q4. `.drop()`을 사용하여 column을 제거할 때, axis 파라미터는 어떤 값으로 지정해야 할까요?**
# - 불필요한 `column`인 `Poster_Link`와 `Overview`를 제거하세요.

# %%
final_revised = final_revised.drop('Poster_Link', axis=1)
final_revised = final_revised.drop('Overview', axis=1)
final_revised.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   711 non-null    object
#  1   Released_Year  711 non-null    int64
#  2   Certificate    711 non-null    object
#  3   Runtime        711 non-null    int64
#  4   Genre          711 non-null    object
#  5   IMDB_Rating    711 non-null    float64
#  6   Meta_score     711 non-null    float64
#  7   Director       711 non-null    object
#  8   Star1          711 non-null    object
#  9   Star2          711 non-null    object
#  10  Star3          711 non-null    object
#  11  Star4          711 non-null    object
#  12  No_of_Votes    711 non-null    float64
#  13  Gross          711 non-null    int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 77.9+ KB

# %% [markdown]
# ##### **Q5. 아래의 과정을 모두 진행한 후, 해당 데이터셋의 마지막 row의 `Star_Name`를 쓰세요.**
# - `.melt()` 를 사용하여 데이터의 구조를 아래와 같이 바꾸세요.
# <img src='https://i.imgur.com/G6DPJMj.png'>
#
#   - `.melt()` 함수의 value_vars와 var_name 파라미터를 설정하여 star1, star2, star3, star4를 `Stars` 컬럼에 저장하세요.
#   - `.melt()` 함수의 value_name 파라미터를 설정하여 star1, star2, star3, star4의 데이터(배우이름)를 `Star_Name` 컬럼에 저장하세요.
# - `.sort_values` 함수를 활용하여 데이터를 Series_Title, Stars 순으로 정렬하세요.
#   - 인덱스를 재설정하세요.

# %%
final_revised_1 = final_revised.copy()
final_revised_1 = pd.melt(final_revised_1, id_vars=['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
       'IMDB_Rating', 'Meta_score', 'Director', 'No_of_Votes', 'Gross'] ,value_vars=['Star1', 'Star2', 'Star3', 'Star4'], var_name='Stars', value_name='Star_Name')

# %%
final_revised_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2844 entries, 0 to 2843
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   2844 non-null   object
#  1   Released_Year  2844 non-null   int64
#  2   Certificate    2844 non-null   object
#  3   Runtime        2844 non-null   int64
#  4   Genre          2844 non-null   object
#  5   IMDB_Rating    2844 non-null   float64
#  6   Meta_score     2844 non-null   float64
#  7   Director       2844 non-null   object
#  8   No_of_Votes    2844 non-null   float64
#  9   Gross          2844 non-null   int64
#  10  Stars          2844 non-null   object
#  11  Star_Name      2844 non-null   object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 266.8+ KB

# %%
final_revised_1 = final_revised_1.sort_values(by=['Series_Title', 'Stars'])

# %%
final_revised_1.iloc[-1, 11]
# Out:
# 'Halina Reijn'

# %% [markdown]
# # **🥇 도전 과제**

# %% [markdown]
# 여러 데이터셋을 합칠 때에는 `concat`, `merge`, `join` 등의 함수를 활용할 수 있습니다.
#
# 이번 과제를 통해서는 Toy Data를 활용하여 `concat`, `merge`, `join`의 결과를 직관적으로 살펴보고, 각 함수의 차이점을 파악해봅니다. 특히 파라미터를 변경해가며 작동원리를 자세히 살펴보세요.

# %%
df1 = pd.DataFrame({'a':['a0','a1','a2','a3'],
                   'b':['b0','b1','b2','b3'],
                   'c':['c0','c1','c2','c3']},
                  index = [0,1,2,3])

df2 = pd.DataFrame({'a':['a2','a3','a4','a5'],
                   'b':['b2','b3','b4','b5'],
                   'c':['c2','c3','c4','c5'],
                   'd':['d2','d3','d4','d5']},
                   index = [2,3,4,5])

# %% [markdown]
# ## **Part 2. concat**
# - axis 파라미터를 조정하여 열방향으로 두 데이터셋을 합쳐보세요.
# - axis 파라미터를 조정하여 행방향으로 두 데이터셋을 합쳐보세요.

# %%
df1
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df2
# Out:
#     a   b   c   d
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5

# %%
pd.concat([df1, df2], ignore_index=False)
# pd.concat([df1, df2], ignore_index=True)
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 2  a2  b2  c2   d2
# 3  a3  b3  c3   d3
# 4  a4  b4  c4   d4
# 5  a5  b5  c5   d5

# %%
# pd.concat([df1, df2], keys=['s1', 's2'])
pd.concat([df1, df2], keys=['s1', 's2'], names=['Series name', 'Row ID'])
# pd.concat([df1, df2], sort=False)
# pd.concat([df1, df2], join='inner')
# pd.concat([df1, df2], axis = 1)
# Out:
#                      a   b   c    d
# Series name Row ID
# s1          0       a0  b0  c0  NaN
#             1       a1  b1  c1  NaN
#             2       a2  b2  c2  NaN
#             3       a3  b3  c3  NaN
# s2          2       a2  b2  c2   d2
#             3       a3  b3  c3   d3
#             4       a4  b4  c4   d4
#             5       a5  b5  c5   d5

# %% [markdown]
# ## **Part 3. merge**
# - `a` column을 기준으로 how 파라미터에 각각 'inner', 'outer', 'left', 'right'를 적용하여 두 데이터셋을 합친 후, 그 차이를 확인해보세요.

# %%
df1.merge(df2)
# Out:
#     a   b   c   d
# 0  a2  b2  c2  d2
# 1  a3  b3  c3  d3

# %%
# df1.merge(df2, how='left')
df1.merge(df2, how='inner')
# Out:
#     a   b   c   d
# 0  a2  b2  c2  d2
# 1  a3  b3  c3  d3

# %%
# df1.merge(df2, how='right')
df1.merge(df2, how='outer')
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2   d2
# 3  a3  b3  c3   d3
# 4  a4  b4  c4   d4
# 5  a5  b5  c5   d5

# %% [markdown]
# ## **Part 4. join**
# - .join()을 사용하여 다음과 같은 결과물을 만들어보세요.
#
# ||a\_x|b\_x|c\_x|a\_y|b\_y|c\_y|d|
# |---|---|---|---|---|---|---|---|
# |**2**|a2|b2|c2|a2|b2|c2|d2|
# |**3**|a3|b3|c3|a3|b3|c3|d3|
# |**4**|NaN|NaN|NaN|a4|b4|c4|d4|
# |**5**|NaN|NaN|NaN|a5|b5|c5|d5|

# %%
df1.join(df2, how='right', lsuffix='a', rsuffix='d')
# Out:
#     aa   ba   ca  ad  bd  cd   d
# 2   a2   b2   c2  a2  b2  c2  d2
# 3   a3   b3   c3  a3  b3  c3  d3
# 4  NaN  NaN  NaN  a4  b4  c4  d4
# 5  NaN  NaN  NaN  a5  b5  c5  d5
